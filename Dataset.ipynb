# %% [markdown]
# <center><h1>Load The Dataset</h1></center>

# %% [markdown]
# In this Small Language Model we will use a dataset called TinyStories from HuggingFace. It is a synthetic dataset of short stories that only contain words that a typical 3 to 4-year-olds usually understand, generated by GPT-3.5 and GPT-4.

# %%
# !pip install dataset

# %%
from datasets import load_dataset
ds = load_dataset("roneneldan/TinyStories")
